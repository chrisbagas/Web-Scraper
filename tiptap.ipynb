# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup


targets = ['clear shampo', 'sunsilk', 'lifebuoy', 'tresemme', 'ponds',
           'glow lovely', 'vaseline', 'pepsodent',
           'closeup', 'lux', 'rexona', 'axe', 'molto', 'sunlight',
           'wipol', 'vixal', 'royco', 'bango', 'sariwangi',  'buavita',
           'head shoulders', 'pantene', 'zinc', 'garnier', 'nivea',
           'marina', 'ciptadent', 'nuvo', 'giv', 'posh',
           'soklin', 'downy', 'garnier'
           'mama lemon', 'supersol', 'yuri porstex', 'masako',
           'sedaap kecap', 'abc kecap manis', 'sosro teh', 'sosro teh asli', 'tong tji',
           'country choice', 'citra', 'superpel','rinso', 'rejoice', 'posh']

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:131.0) Gecko/20100101 Firefox/131.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    # 'Accept-Encoding': 'gzip, deflate, br, zstd',
    'X-Requested-With': 'XMLHttpRequest',
    'x-api-key': '29ea3dcf-67c3-45f6-b5c4-d2628f7e09fa',
    'Origin': 'https://shop.tiptop.co.id',
    'Connection': 'keep-alive',
    'Referer': 'https://shop.tiptop.co.id/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-site',
    'If-None-Match': 'W/17183-jpdI/sqJpt20+d2buSTmZacc8PE',
}

params = {
    'name': 'clear',
    'outletId': '63cc7d04e5df8b2ef7ee517a',
}

response = requests.get('https://api.tiptop.co.id/api/web//product-search', params=params, headers=headers, verify=False)
import json

# Assuming `response.json()` contains the JSON data
json_data = response.json()

# Pretty-print the JSON data
print(json.dumps(json_data, indent=4))
# Out:
# C:\Users\Christopher Bagas\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.tiptop.co.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {
#     "status": true,
#     "statusCode": 200,
#     "data": [
#         {
#             "main_image": {
#                 "small_image": "https://assets.tiptop.co.id/01183700101a.jpg",
#                 "large_image": "https://assets.tiptop.co.id/01183700101a.jpg",
#                 "link": "",
#                 "active": null
#             },
#             "info_product": {
#                 "key1": "Berat",
#                 "key2": "",
#                 "pricing_stock": [
#                     {
#                         "_id": "649b1431c080d66ec10923bd",
#                         "name": "160ML",
# ...
