# %%
import pandas as pd

df = pd.read_excel('../SUPERINDO_241003.xlsx')
df.head()
# Out:
#                                         productName  basePrice  finalPrice  \
# 0       CLEAR SHAMPOO ANTI DANDRUFF COMPLETE SOFT/C      32990       32990
# 1        CLEAR SHAMPOO ANTI DANDRUFF FRESH COOL LMN      59390       59390
# 2      CLEAR SHAMPOO ANTI DANDRUFF ICE COOL MENTHOL      59390       59390
# 3        CLEAR SHAMPOO ANTI DANDRUFF MEN COOL SPORT      59390       59390
# 4  CLEAR SHAMPOO ANTI DANDRUFF PUMP ICE COOL MENTHL      98590       98590
#
#     unit location
# 0  160ml  Jakarta
# 1  300ml  Jakarta
# 2  300ml  Jakarta
# 3  300ml  Jakarta
# 4  660ml  Jakarta

# %%
targets = ['clear shampoo', 'sunsilk shampoo', 'lifebuoy', 'tresemme shampoo', 'ponds',
           'glow &', 'vaseline', 'pepsodent pasta gigi',
           'closeup', 'lifebuoy sabun mandi', 'lux botanicals', 'rexona', 'axe', 'molto', 'sunlight',
           'wipol', 'vixal', 'royco', 'bango kecap', 'sariwangi', 'sarimurni', 'buavita',
           'head & shoulders', 'pantene shampoo', 'zinc', 'garnier', 'nivea',
           'marina', 'ciptadent pasta gigi', 'nuvo', 'giv', 'posh men body spray',
           'so klin',  'downy pelembut','mama lemon', 'super sol', 
           'yuri porstex', 'masako penyedap rasa ayam',
           'sedaap kecap', 'abc kecap manis', 'sosro teh', 'tong tji', 'teh bendera',
           'country choice', 'citra', 'super pel','rinso']

# Group by location and identify missing products
missing_products_by_location = {}

for location, group in df.groupby('location'):
    available_products = set()
    
    # Check for each product in the group if it matches a target
    for product in group['productName']:
        for target in targets:
            if target.lower() in product.lower():
                available_products.add(target)
    
    # Find which targets are missing
    missing_products = set(targets) - available_products
    missing_products_by_location[location] = missing_products

# Print missing products by location
for location, missing in missing_products_by_location.items():
    print(f"Location: {location}")
    if missing:
        print("Missing products:")
        for product in missing:
            print(f" - {product}")
    else:
        print("All products available.")
    print()
# Out:
# Location: Jakarta
# Missing products:
#  - glow &
#  - soklin pewangi
#  - sosro teh asli
#  - soklin liquid
#  - soklin softergent
#  - masako penyedap rasa ayam
#  - pantene sampo
#  - head & shoulders sampo
#  - lux botanicals
#  - posh men body spray
#  - sunsilk sampo
#  - closeup
#  - mama lemon
#  - sosro teh
#  - clear sampo
#  - teh bendera
#  - supersol
#  - sarimurni
#  - superpel
